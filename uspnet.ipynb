# %%
# !git clone https://github.com/JunboShen/USPNet.git
# !cd ./USPNet
# !conda env create -f /kaggle/working/USPNet/environment.yml
# Out:
# Cloning into 'USPNet'...
# remote: Enumerating objects: 156, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 156 (delta 82), reused 99 (delta 40), pack-reused 0
# Receiving objects: 100% (156/156), 50.77 KiB | 10.15 MiB/s, done.
# Resolving deltas: 100% (82/82), done.
# Retrieving notices: ...working... done
# - WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# ...

# %%
# !conda env create -f /kaggle/working/USPNet/environment.yml
# Out:
# CondaValueError: prefix already exists: /opt/conda/envs/uspnet

# %%
# !conda activate uspnet
# Out:
# usage: conda [-h] [--no-plugins] [-V] COMMAND ...
# conda: error: argument COMMAND: invalid choice: 'activate' (choose from 'clean', 'compare', 'config', 'create', 'info', 'init', 'install', 'list', 'notices', 'package', 'remove', 'uninstall', 'rename', 'run', 'search', 'update', 'upgrade', 'doctor', 'env')
